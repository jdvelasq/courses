# %% [markdown]
# Redes neuronales recurrentes
# ===

# %% [markdown]
# * *60 min* | Última modificación: Julio 12, 2019.

# %% [markdown]
# Adaptado de https://www.tensorflow.org/tutorials/sequences/recurrent?hl=es
