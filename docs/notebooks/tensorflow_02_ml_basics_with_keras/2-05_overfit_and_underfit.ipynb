# %% [markdown]
# Técnicas para evitar el sobreajuste de modelos --- 37:15 min
# ===

# %% [markdown]
# * Última modificación: Mayo 10, 2021 | [YouTube](https://youtu.be/vGkJSNjFLZs)

# %% [markdown]
# Adaptado de:
#
# * https://www.tensorflow.org/tutorials/keras/overfit_and_underfit

# %%
#
# Paquetes a instalar en Google Colab
#

# !pip install git+https://github.com/tensorflow/docs

# %% [markdown]
# ## Higgs Dataset

# %%
#
# Descarga el archivo en formato csv.gz (comprimido)
# 
# El dataset original contiene 11.000.000 de ejemplos 
# y 28 variables independientes. La variable dependiente
# es binaria.
#
# Para este ejemplo, y tal como se hace en el tutorial
# original de TensorFlow se usaran 11.000 ejemplos. Ya
# que el tiempo de descarga es largo debido al tamaño 
# del archivo original, se creo un archivo que contiene
# unicamente los ejemplos usados en esta lección.
#
# !wget https://raw.githubusercontent.com/jdvelasq/datalabs/master/datasets/HIGGS-tiny.csv.gz

# %%
import tensorflow as tf

#
# Número de variables independientes
#
FEATURES = 28

#
# Lee directamente los datos comprimidos
# en formato gz
#
ds = tf.data.experimental.CsvDataset(
    #
    # Nombre del archivo
    #
    "HIGGS-tiny.csv.gz",
    #
    # Valores por defecto para las columnas
    # del dataset: float32, float64, int32,
    #  int64, string.
    #
    [
        float(),
    ]
    * (FEATURES + 1),
    #
    # Formato:
    # - "": sin compresión
    # - "ZLIB"
    # - "GZIP"
    #
    compression_type="GZIP",
)

#
# La primera columa es la variable dependiente
# y las demás corresponden a las variables
# independientes. La función empaqueta los datos
# aplicando la función pack_row a cada fila del
# dataframe
#
def pack_row(*row):
    label = row[0]
    features = tf.stack(row[1:], 1)
    return features, label


#
#  En vez de aplicar la función individualmente a
#  cada patrón, primero se empaqueta en grupos de
#  10.000 patrónes, se aplica la función map(), y
#  finalmente se retornan los registros individuales
#
packed_ds = ds.batch(10000).map(pack_row).unbatch()

#
# Histograma de las variables independientes.
# Son aproximadamente normales
#
import matplotlib.pyplot as plt

for features, label in packed_ds.batch(1000).take(1):
    print(features[0])
    plt.hist(features.numpy().flatten(), bins=101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %% [markdown]
# ## Conjuntos de entrenamiento y validación

# %%
#
# Usa los primeros 1000 para validacion
#
N_VALIDATION = 1000
N_TRAIN = 10000
BUFFER_SIZE = 10000
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN // BATCH_SIZE

validate_ds = packed_ds.take(N_VALIDATION).cache()

#
# Ignora los primeros 1000 (validación) y toma los 
# siguientes 10.000 para entrenamiento. El método 
# cache hace que no se relean registros del 
# archivo en disco en cada epoch.
#
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

#
# Define el tamaño de los bloques
#
validate_ds = validate_ds.batch(BATCH_SIZE)

#
# Mezcla los patrones de entrenamiento
#
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %% [markdown]
# ## Variación de la tasa de aprendizaje

# %%
import numpy as np


#
# La siguiente función grafica tres esquemas
#  diferentes de variación de la tasa de aprendizaje
#
def plot_schedules():

    plt.figure(figsize=(12, 4))

    step = np.linspace(0, 100000)

    plt.subplot(1, 3, 1)
    schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
        0.001,
        decay_steps=STEPS_PER_EPOCH * 1000,
        decay_rate=1,
        staircase=False,
    )
    lr = schedule(step)
    plt.plot(step / STEPS_PER_EPOCH, lr)

    plt.subplot(1, 3, 2)
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=0.01,
        decay_steps=STEPS_PER_EPOCH * 1000,
        decay_rate=0.5,
        staircase=False,
    )
    lr = schedule(step)
    plt.plot(step / STEPS_PER_EPOCH, lr)

    plt.subplot(1, 3, 3)
    schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        initial_learning_rate=0.01,
        decay_steps=STEPS_PER_EPOCH * 5000,
        end_learning_rate=0.0002,
        power=0.3,
        cycle=False,
    )
    lr = schedule(step)
    plt.plot(step / STEPS_PER_EPOCH, lr)

    plt.show()


plot_schedules()

# %% [markdown]
# ## Callbacks

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling

#
# Define el directorio de trabajo para almacenar
# la información que requiere TensorBoard
#
LOGDIR = "/tmp/tensorboard_logs"

#
# Borra el directorio si existe
#
# !rm -rf {LOGDIR}


#
# Define las funciones que se llamaran en cada
# iteración del entrenamiento. La función 
# retorna una lista de callbacks.
#
def get_callbacks(name):
    return [
        # 
        # Simplemente imprime un "." en cada epoch
        #
        tfdocs.modeling.EpochDots(),
        
        #
        # Los callbacks son utilidades que se llaman durante el
        # entrenamiento de un modelo.
        #
        # EarlyStopping detiene el entrenamiento si la métrica
        # monitoreada no mejora durante "patiente" iteraciones
        #
        tf.keras.callbacks.EarlyStopping(
            monitor="val_binary_crossentropy",
            patience=200,
            verbose=0,
        ),
        
        #
        # Almacena la información requerida para visualizar
        # los resultados en TensorBoard
        #
        tf.keras.callbacks.TensorBoard(LOGDIR + "/" + name),
    ]

# %%
#
# Esta es una función auxiliar que recibe
#  un modelo y un string para identificarlo.
#
def compile_and_fit(model, name):

    MAX_EPOCHS = 10000

    lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
        0.001,
        decay_steps=STEPS_PER_EPOCH * 1000,
        decay_rate=1,
        staircase=False,
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr_schedule),
        loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[
            tf.keras.losses.BinaryCrossentropy(
                from_logits=True,
                name="binary_crossentropy",
            ),
            "accuracy",
        ],
    )

    model.summary()

    history = model.fit(
        train_ds,
        steps_per_epoch=STEPS_PER_EPOCH,
        epochs=MAX_EPOCHS,
        validation_data=validate_ds,
        callbacks=get_callbacks(name),
        verbose=0,
    )

    return history

# %%
#
# Crea modelos con distintos tamaños y cantidad
# de parámetros y los entrena.
#
tiny_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            16,
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(1),
    ]
)

small_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            16,
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            16,
            activation="elu",
        ),
        tf.keras.layers.Dense(1),
    ]
)

medium_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            64,
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            64,
            activation="elu",
        ),
        tf.keras.layers.Dense(
            64,
            activation="elu",
        ),
        tf.keras.layers.Dense(1),
    ]
)

large_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dense(1),
    ]
)

# %%
#
# Crea un diccionario para guardar los resultados
# de las corridas
#
size_histories = {}

# %%
#
# El siguiente grupo de celdas crea modelos de
# distintos tamños y los entrena. Almacena la
# historia retornada por cada modelo
#
size_histories["Tiny"] = compile_and_fit(tiny_model, "sizes/Tiny")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4790,  binary_crossentropy:0.7541,  loss:0.7541,  val_accuracy:0.5090,  val_binary_crossentropy:0.7112,  val_loss:0.7112,
# ....................................................................................................
# Epoch: 100, accuracy:0.5960,  binary_crossentropy:0.6272,  loss:0.6272,  val_accuracy:0.5580,  val_binary_crossentropy:0.6343,  val_loss:0.6343,
# ....................................................................................................
# Epoch: 200, accuracy:0.6079,  binary_crossentropy:0.6194,  loss:0.6194,  val_accuracy:0.5830,  val_binary_crossentropy:0.6258,  val_loss:0.6258,
# ....................................................................................................
# Epoch: 300, accuracy:0.6212,  binary_crossentropy:0.6125,  loss:0.6125,  val_accuracy:0.5900,  val_binary_crossentropy:0.6227,  val_loss:0.6227,
# ....................................................................................................
# Epoch: 400, accuracy:0.6323,  binary_crossentropy:0.6069,  loss:0.6069,  val_accuracy:0.5970,  val_binary_crossentropy:0.6201,  val_loss:0.6201,
# ....................................................................................................
# Epoch: 500, accuracy:0.6398,  binary_crossentropy:0.6024,  loss:0.6024,  val_accuracy:0.6120,  val_binary_crossentropy:0.6158,  val_loss:0.6158,
# ....................................................................................................
# Epoch: 600, accuracy:0.6453,  binary_crossentropy:0.5979,  loss:0.5979,  val_accuracy:0.6210,  val_binary_crossentropy:0.6112,  val_loss:0.6112,
# ....................................................................................................
# Epoch: 700, accuracy:0.6552,  binary_crossentropy:0.5947,  loss:0.5947,  val_accuracy:0.6230,  val_binary_crossentropy:0.6079,  val_loss:0.6079,
# ....................................................................................................
# Epoch: 800, accuracy:0.6545,  binary_crossentropy:0.5914,  loss:0.5914,  val_accuracy:0.6350,  val_binary_crossentropy:0.6037,  val_loss:0.6037,
# ....................................................................................................
# Epoch: 900, accuracy:0.6593,  binary_crossentropy:0.5888,  loss:0.5888,  val_accuracy:0.6370,  val_binary_crossentropy:0.6014,  val_loss:0.6014,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6644,  binary_crossentropy:0.5862,  loss:0.5862,  val_accuracy:0.6410,  val_binary_crossentropy:0.5992,  val_loss:0.5992,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6672,  binary_crossentropy:0.5843,  loss:0.5843,  val_accuracy:0.6440,  val_binary_crossentropy:0.5971,  val_loss:0.5971,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6711,  binary_crossentropy:0.5826,  loss:0.5826,  val_accuracy:0.6400,  val_binary_crossentropy:0.5971,  val_loss:0.5971,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6671,  binary_crossentropy:0.5813,  loss:0.5813,  val_accuracy:0.6590,  val_binary_crossentropy:0.5937,  val_loss:0.5937,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6644,  binary_crossentropy:0.5808,  loss:0.5808,  val_accuracy:0.6600,  val_binary_crossentropy:0.5913,  val_loss:0.5913,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6715,  binary_crossentropy:0.5784,  loss:0.5784,  val_accuracy:0.6560,  val_binary_crossentropy:0.5897,  val_loss:0.5897,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6690,  binary_crossentropy:0.5770,  loss:0.5770,  val_accuracy:0.6590,  val_binary_crossentropy:0.5876,  val_loss:0.5876,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6785,  binary_crossentropy:0.5758,  loss:0.5758,  val_accuracy:0.6530,  val_binary_crossentropy:0.5873,  val_loss:0.5873,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6723,  binary_crossentropy:0.5753,  loss:0.5753,  val_accuracy:0.6680,  val_binary_crossentropy:0.5859,  val_loss:0.5859,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6844,  binary_crossentropy:0.5750,  loss:0.5750,  val_accuracy:0.6500,  val_binary_crossentropy:0.5866,  val_loss:0.5866,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6865,  binary_crossentropy:0.5732,  loss:0.5732,  val_accuracy:0.6620,  val_binary_crossentropy:0.5852,  val_loss:0.5852,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6837,  binary_crossentropy:0.5726,  loss:0.5726,  val_accuracy:0.6790,  val_binary_crossentropy:0.5845,  val_loss:0.5845,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6855,  binary_crossentropy:0.5720,  loss:0.5720,  val_accuracy:0.6710,  val_binary_crossentropy:0.5842,  val_loss:0.5842,
# ....................................................................................................
# Epoch: 2300, accuracy:0.6866,  binary_crossentropy:0.5711,  loss:0.5711,  val_accuracy:0.6640,  val_binary_crossentropy:0.5843,  val_loss:0.5843,
# ....................................................................................................
# Epoch: 2400, accuracy:0.6846,  binary_crossentropy:0.5713,  loss:0.5713,  val_accuracy:0.6780,  val_binary_crossentropy:0.5836,  val_loss:0.5836,
# ....................................................................................................
# Epoch: 2500, accuracy:0.6817,  binary_crossentropy:0.5705,  loss:0.5705,  val_accuracy:0.6830,  val_binary_crossentropy:0.5833,  val_loss:0.5833,
# ....................................................................................................
# Epoch: 2600, accuracy:0.6849,  binary_crossentropy:0.5696,  loss:0.5696,  val_accuracy:0.6690,  val_binary_crossentropy:0.5835,  val_loss:0.5835,
# ...........................................................................

# %%
size_histories["Small"] = compile_and_fit(small_model, "sizes/Small")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4870,  binary_crossentropy:0.7541,  loss:0.7541,  val_accuracy:0.4740,  val_binary_crossentropy:0.7194,  val_loss:0.7194,
# ....................................................................................................
# Epoch: 100, accuracy:0.6185,  binary_crossentropy:0.6147,  loss:0.6147,  val_accuracy:0.6040,  val_binary_crossentropy:0.6114,  val_loss:0.6114,
# ....................................................................................................
# Epoch: 200, accuracy:0.6605,  binary_crossentropy:0.5915,  loss:0.5915,  val_accuracy:0.6410,  val_binary_crossentropy:0.5963,  val_loss:0.5963,
# ....................................................................................................
# Epoch: 300, accuracy:0.6726,  binary_crossentropy:0.5778,  loss:0.5778,  val_accuracy:0.6410,  val_binary_crossentropy:0.5918,  val_loss:0.5918,
# ....................................................................................................
# Epoch: 400, accuracy:0.6841,  binary_crossentropy:0.5703,  loss:0.5703,  val_accuracy:0.6600,  val_binary_crossentropy:0.5921,  val_loss:0.5921,
# ....................................................................................................
# Epoch: 500, accuracy:0.6896,  binary_crossentropy:0.5656,  loss:0.5656,  val_accuracy:0.6460,  val_binary_crossentropy:0.5984,  val_loss:0.5984,
# .............................

# %%
size_histories["Medium"] = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4889,  binary_crossentropy:0.6948,  loss:0.6948,  val_accuracy:0.5000,  val_binary_crossentropy:0.6810,  val_loss:0.6810,
# ....................................................................................................
# Epoch: 100, accuracy:0.7175,  binary_crossentropy:0.5272,  loss:0.5272,  val_accuracy:0.6600,  val_binary_crossentropy:0.6033,  val_loss:0.6033,
# ....................................................................................................
# Epoch: 200, accuracy:0.7844,  binary_crossentropy:0.4319,  loss:0.4319,  val_accuracy:0.6450,  val_binary_crossentropy:0.6944,  val_loss:0.6944,
# ................................................................

# %%
size_histories["large"] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5080,  binary_crossentropy:0.8088,  loss:0.8088,  val_accuracy:0.5740,  val_binary_crossentropy:0.6910,  val_loss:0.6910,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0020,  loss:0.0020,  val_accuracy:0.6730,  val_binary_crossentropy:1.7673,  val_loss:1.7673,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6710,  val_binary_crossentropy:2.3945,  val_loss:2.3945,
# ..................

# %%
size_histories["Tiny"] = compile_and_fit(tiny_model, "sizes/Tiny")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.6839,  binary_crossentropy:0.5710,  loss:0.5710,  val_accuracy:0.6830,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 100, accuracy:0.6859,  binary_crossentropy:0.5695,  loss:0.5695,  val_accuracy:0.6870,  val_binary_crossentropy:0.5845,  val_loss:0.5845,
# ....................................................................................................
# Epoch: 200, accuracy:0.6885,  binary_crossentropy:0.5677,  loss:0.5677,  val_accuracy:0.6730,  val_binary_crossentropy:0.5835,  val_loss:0.5835,
# ....................................................................................................
# Epoch: 300, accuracy:0.6897,  binary_crossentropy:0.5659,  loss:0.5659,  val_accuracy:0.6700,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ..............................................................................................

# %% [markdown]
# ## Resultados obtenidos para los modelos

# %%
import tensorflow_docs.plots

#
# A continuación se grafican los resultados obtenidos para
# los modelos estimados anteriormente. Los modelos Medium
# y Large presentan claramente sobre-entrenamiento
# (métrica de pérdida creciente para el conjunto de
# validación y metríca descendente para el conjunto
# de entrenamiento)
#
# Note que el modelo Tiny no presenta sobreajuste.
#
plt.figure(figsize=(12, 6))
plotter = tfdocs.plots.HistoryPlotter(
    metric="binary_crossentropy",
    smoothing_std=10,
)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
plt.show()

# %%
#
# Esta es la misma gráfica anterior, pero con
# escala logaritmica en el eje X
#
plt.figure(figsize=(12, 6))
plotter.plot(size_histories)
a = plt.xscale("log")
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
plt.show()

# %% [markdown]
# ## Visualización en TensorBoard

# %% [markdown]
# ```python
# #
# # Carga la extensión de TensorBoard
# #
# %load_ext tensorboard
# ```

# %% [markdown]
# ```python
# #
# # Carga TensorBoard al notebook
# #
# %tensorboard --host=0.0.0.0 --logdir {LOGDIR}
# ```

# %% [markdown]
# ![TensorBoard](assets/tensorboard-gui.png)

# %% [markdown]
# ## Estrategias para evitar el sobreajuste

# %%
#
# Borra la carpeta con los resulados para la regularizacion
#
# !rm -rf {LOGDIR + "/regularizers"}

#
# Copia los resultados del modelo Tiny para efectos
# de comparación
#
# !mkdir -p {LOGDIR + "/regularizers"}
# !cp -R {LOGDIR + "/sizes/Tiny"}  {LOGDIR + "/regularizers/Tiny"}


#
# Diccionario para almacenar los resultados de los modelos
#
regularizer_histories = {}

#
# Copia el resultado del modelo Tiny (que no tiene
# sobreajuste)
#
regularizer_histories["Tiny"] = size_histories["Tiny"]

# %%
#
# Regularización L1
#
L1_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1(
                l1=0.001,
            ),
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1(
                l1=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1(
                l1=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1(
                l1=0.001,
            ),
        ),
        tf.keras.layers.Dense(1),
    ]
)

regularizer_histories["L1"] = compile_and_fit(L1_model, "regularizers/L1")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4904,  binary_crossentropy:0.7294,  loss:26.7411,  val_accuracy:0.5120,  val_binary_crossentropy:0.6771,  val_loss:21.4079,
# ....................................................................................................
# Epoch: 100, accuracy:0.4738,  binary_crossentropy:0.6918,  loss:0.7788,  val_accuracy:0.4600,  val_binary_crossentropy:0.6903,  val_loss:0.7772,
# ....................................................................................................
# Epoch: 200, accuracy:0.4738,  binary_crossentropy:0.6918,  loss:0.7707,  val_accuracy:0.4600,  val_binary_crossentropy:0.6903,  val_loss:0.7690,
# ..

# %%
#
# Regularización L2
#
L2_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L2(
                l2=0.001,
            ),
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L2(
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L2(
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L2(
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(1),
    ]
)

regularizer_histories["L2"] = compile_and_fit(L2_model, "regularizers/L2")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4999,  binary_crossentropy:0.7994,  loss:2.3109,  val_accuracy:0.4700,  val_binary_crossentropy:0.6872,  val_loss:2.1163,
# ....................................................................................................
# Epoch: 100, accuracy:0.6610,  binary_crossentropy:0.5943,  loss:0.6186,  val_accuracy:0.6300,  val_binary_crossentropy:0.5889,  val_loss:0.6134,
# ....................................................................................................
# Epoch: 200, accuracy:0.6757,  binary_crossentropy:0.5839,  loss:0.6067,  val_accuracy:0.6420,  val_binary_crossentropy:0.5861,  val_loss:0.6089,
# ....................................................................................................
# Epoch: 300, accuracy:0.6798,  binary_crossentropy:0.5735,  loss:0.5994,  val_accuracy:0.6870,  val_binary_crossentropy:0.5774,  val_loss:0.6034,
# ....................................................................................................
# Epoch: 400, accuracy:0.6812,  binary_crossentropy:0.5731,  loss:0.5983,  val_accuracy:0.6890,  val_binary_crossentropy:0.5780,  val_loss:0.6031,
# ....................................................................................................
# Epoch: 500, accuracy:0.6978,  binary_crossentropy:0.5613,  loss:0.5876,  val_accuracy:0.6860,  val_binary_crossentropy:0.5735,  val_loss:0.5997,
# ....................................................................................................
# Epoch: 600, accuracy:0.7055,  binary_crossentropy:0.5521,  loss:0.5793,  val_accuracy:0.6770,  val_binary_crossentropy:0.5778,  val_loss:0.6051,
# ....................................................................................................
# Epoch: 700, accuracy:0.7050,  binary_crossentropy:0.5506,  loss:0.5780,  val_accuracy:0.6880,  val_binary_crossentropy:0.5754,  val_loss:0.6028,
# ....................................................................................................
# Epoch: 800, accuracy:0.7114,  binary_crossentropy:0.5440,  loss:0.5724,  val_accuracy:0.6900,  val_binary_crossentropy:0.5703,  val_loss:0.5987,
# ....................................................................................................
# Epoch: 900, accuracy:0.7167,  binary_crossentropy:0.5355,  loss:0.5645,  val_accuracy:0.6730,  val_binary_crossentropy:0.5805,  val_loss:0.6094,
# ..................

# %%
#
# Regularización L1l2
#
L1L2_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1L2(
                l1=0.001,
                l2=0.001,
            ),
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1L2(
                l1=0.001,
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1L2(
                l1=0.001,
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(
            512,
            activation="elu",
            kernel_regularizer=tf.keras.regularizers.L1L2(
                l1=0.001,
                l2=0.001,
            ),
        ),
        tf.keras.layers.Dense(1),
    ]
)

regularizer_histories["L1L2"] = compile_and_fit(L1L2_model, "regularizers/L1L2")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4934,  binary_crossentropy:0.7159,  loss:27.2194,  val_accuracy:0.4600,  val_binary_crossentropy:0.6838,  val_loss:21.0454,
# ....................................................................................................
# Epoch: 100, accuracy:0.4738,  binary_crossentropy:0.6918,  loss:0.7800,  val_accuracy:0.4600,  val_binary_crossentropy:0.6904,  val_loss:0.7785,
# ....................................................................................................
# Epoch: 200, accuracy:0.4738,  binary_crossentropy:0.6918,  loss:0.7748,  val_accuracy:0.4600,  val_binary_crossentropy:0.6903,  val_loss:0.7733,
# ..

# %%
plt.figure(figsize=(12, 6))
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
plt.show()

# %%
result = L2_model(features)
regularization_loss = tf.add_n(L2_model.losses)

# %%
#
# Dropout
#
dropout_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1),
    ]
)

regularizer_histories["dropout"] = compile_and_fit(
    dropout_model, "regularizers/dropout"
)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5004,  binary_crossentropy:0.8095,  loss:0.8095,  val_accuracy:0.5520,  val_binary_crossentropy:0.6795,  val_loss:0.6795,
# ....................................................................................................
# Epoch: 100, accuracy:0.6579,  binary_crossentropy:0.5960,  loss:0.5960,  val_accuracy:0.6830,  val_binary_crossentropy:0.5750,  val_loss:0.5750,
# ....................................................................................................
# Epoch: 200, accuracy:0.6930,  binary_crossentropy:0.5563,  loss:0.5563,  val_accuracy:0.6870,  val_binary_crossentropy:0.5844,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 300, accuracy:0.7205,  binary_crossentropy:0.5097,  loss:0.5097,  val_accuracy:0.6710,  val_binary_crossentropy:0.6107,  val_loss:0.6107,
# ........

# %%
plt.figure(figsize=(12, 6))
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
#
# L2 + Dropout
#
combined_model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(
            512,
            kernel_regularizer=tf.keras.regularizers.l2(0.0001),
            activation="elu",
            input_shape=(FEATURES,),
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            kernel_regularizer=tf.keras.regularizers.l2(0.0001),
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            kernel_regularizer=tf.keras.regularizers.l2(0.0001),
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(
            512,
            kernel_regularizer=tf.keras.regularizers.l2(0.0001),
            activation="elu",
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1),
    ]
)

regularizer_histories["combined"] = compile_and_fit(
    combined_model, "regularizers/combined"
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5008,  binary_crossentropy:0.7947,  loss:0.9532,  val_accuracy:0.5480,  val_binary_crossentropy:0.6796,  val_loss:0.8374,
# ....................................................................................................
# Epoch: 100, accuracy:0.6514,  binary_crossentropy:0.6034,  loss:0.6338,  val_accuracy:0.6580,  val_binary_crossentropy:0.5841,  val_loss:0.6142,
# ....................................................................................................
# Epoch: 200, accuracy:0.6642,  binary_crossentropy:0.5865,  loss:0.6126,  val_accuracy:0.6680,  val_binary_crossentropy:0.5788,  val_loss:0.6048,
# ....................................................................................................
# Epoch: 300, accuracy:0.6687,  binary_crossentropy:0.5833,  loss:0.6123,  val_accuracy:0.6880,  val_binary_crossentropy:0.5593,  val_loss:0.5883,
# ....................................................................................................
# Epoch: 400, accuracy:0.6750,  binary_crossentropy:0.5762,  loss:0.6073,  val_accuracy:0.6920,  val_binary_crossentropy:0.5538,  val_loss:0.5850,
# ....................................................................................................
# Epoch: 500, accuracy:0.6721,  binary_crossentropy:0.5714,  loss:0.6043,  val_accuracy:0.6760,  val_binary_crossentropy:0.5557,  val_loss:0.5885,
# ....................................................................................................
# Epoch: 600, accuracy:0.6862,  binary_crossentropy:0.5650,  loss:0.6002,  val_accuracy:0.6590,  val_binary_crossentropy:0.5628,  val_loss:0.5980,
# ....................................................................................................
# Epoch: 700, accuracy:0.6843,  binary_crossentropy:0.5606,  loss:0.5982,  val_accuracy:0.6840,  val_binary_crossentropy:0.5500,  val_loss:0.5875,
# ....................................................................................................
# Epoch: 800, accuracy:0.6908,  binary_crossentropy:0.5560,  loss:0.5955,  val_accuracy:0.6980,  val_binary_crossentropy:0.5490,  val_loss:0.5885,
# ....................................................................................................
# Epoch: 900, accuracy:0.6954,  binary_crossentropy:0.5503,  loss:0.5913,  val_accuracy:0.7000,  val_binary_crossentropy:0.5510,  val_loss:0.5920,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6950,  binary_crossentropy:0.5486,  loss:0.5911,  val_accuracy:0.6960,  val_binary_crossentropy:0.5469,  val_loss:0.5894,
# ....................................................................................................
# Epoch: 1100, accuracy:0.7015,  binary_crossentropy:0.5426,  loss:0.5863,  val_accuracy:0.6980,  val_binary_crossentropy:0.5503,  val_loss:0.5940,
# ....................................................................................................
# Epoch: 1200, accuracy:0.7029,  binary_crossentropy:0.5418,  loss:0.5866,  val_accuracy:0.6960,  val_binary_crossentropy:0.5526,  val_loss:0.5973,
# ...............................................

# %%
plt.figure(figsize=(12, 6))
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
